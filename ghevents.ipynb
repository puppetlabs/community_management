# %%
import pandas as pd
import numpy as np
from datetime import datetime
from pandas.api.types import CategoricalDtype

data = pd.read_csv('results.csv')
data = data.astype({
  'created_at': 'datetime64[s]', 
  'resolved_at': 'datetime64[s]',
  'created_at_quarter': 'string',
  'resolved_at_quarter': 'string', 
  'tier': CategoricalDtype(categories=['Gold', 'Silver', 'Bronze', 'unknown'], ordered=True),
  'labels': 'category'
  })

# %%
data['c_counter'] = (data['days_to_resolution'] * 0) + 1
data['c_count'] = data.groupby('repo')[['c_counter']].transform(sum)

# data = data.infer_objects()
# data.set_index('created_at_quarter')
by_raq = data.sort_values('resolved_at_quarter').reset_index(drop=True)
# by_tier = data.sort_values('tier').reset_index(drop=True)
by_tier_contributions = data.sort_values(by=['tier', 'c_count'], ascending=[True, False])

# %%
data['labels'].cat.categories
data['labels'].cat
# data.dtypes

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from numpy import median, sum, count_nonzero

fig, axs = plt.subplots(nrows=1, figsize=(30,10))
sns.violinplot(x="resolved_at_quarter", y="days_to_resolution", data=by_raq, ax=axs)
# sns.pointplot(x="resolved_at_quarter", y="days_to_resolution", data=by_raq, ax=axs[1])
# # sns.pointplot(x="resolved_at_quarter", y="days_to_resolution", estimator=median, data=raq, ax=axs[2])
# sns.barplot(x="tier", y="days_to_resolution", data=data, ax=axs[2], order=['Gold', 'Silver', 'Bronze'])
# sns.barplot(x="tier", y='contribution_count', estimator=sum, data=data, ax=axs[0], order=['Gold', 'Silver', 'Bronze'])
# Out:
# <AxesSubplot:xlabel='resolved_at_quarter', ylabel='days_to_resolution'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from numpy import median, sum, count_nonzero

fig, axs = plt.subplots(nrows=1, figsize=(30,10))

repo_chart = sns.barplot(x="repo", y='days_to_resolution', hue='tier', hue_order=['Gold', 'Silver', 'Bronze', 'unknown'], data=by_tier_contributions, ax=axs)
repo_chart.set_xticklabels(repo_chart.get_xticklabels(), rotation=45, horizontalalignment='right')
sns.pointplot(x="repo", y='c_counter', estimator=sum, data=by_tier_contributions, ax=axs.twinx(), join=False)
# Out:
# <AxesSubplot:label='1c85b9bc-0da7-4773-b1ba-4a6664329ec0', xlabel='repo', ylabel='c_counter'>

# %%
by_tier_contributions
# Out:
#                created_at created_at_quarter                           repo  \
# 23    2019-07-16 07:03:14            2019-Q3   puppetlabs/puppetlabs-apache
# 161   2019-08-15 08:22:11            2019-Q3   puppetlabs/puppetlabs-apache
# 226   2019-08-05 09:05:05            2019-Q3   puppetlabs/puppetlabs-apache
# 252   2019-08-27 14:39:30            2019-Q3   puppetlabs/puppetlabs-apache
# 280   2019-08-08 14:40:12            2019-Q3   puppetlabs/puppetlabs-apache
# ...                   ...                ...                            ...
# 9149  2019-03-22 14:41:56            2019-Q1  puppetlabs/dependency_checker
# 9662  2021-01-29 13:49:56            2021-Q1  puppetlabs/dependency_checker
# 10332 2019-04-26 12:30:09            2019-Q2  puppetlabs/dependency_checker
# 10846 2021-03-30 09:23:46            2021-Q1  puppetlabs/dependency_checker
# 11069 2021-04-15 00:16:07            2021-Q2  puppetlabs/dependency_checker
#
#       repo_tag               created_by     affiliation         resolved_at  \
# 23      module                   lionce             iac 2019-07-16 09:35:57
# 161     module               sheenaajay             iac 2019-08-15 08:33:48
# 226     module                   aukesj       community 2019-08-20 19:58:22
# 252     module                  tphoney             iac 2019-08-28 10:42:32
# 280     module               sheenaajay             iac 2019-08-30 09:53:42
# ...        ...                      ...             ...                 ...
# 9149      tool                   eimlav             iac 2019-03-22 14:55:12
# 9662      tool  dependabot-preview[bot]             bot 2021-02-01 09:04:27
# 10332     tool                   eimlav             iac 2019-04-26 12:55:51
# 10846     tool              david22swan             iac 2021-03-30 12:30:06
# 11069     tool                  smortex  puppet-trusted 2021-04-19 12:34:35
#
#       resolved_at_quarter      merged_by merged_aff resolution  \
# 23                2019-Q3  carabasdaniel        iac     merged
# 161               2019-Q3     sheenaajay        iac   rejected
# 226               2019-Q3  ThoughtCrhyme        iac     merged
# 252               2019-Q3     sheenaajay        iac     merged
# 280               2019-Q3     sheenaajay        iac   rejected
# ...                   ...            ...        ...        ...
# 9149              2019-Q1    david22swan        iac     merged
# 9662              2021-Q1         DavidS        iac     merged
# 10332             2019-Q2         pmcmaw        iac     merged
# 10846             2021-Q1         pmcmaw        iac     merged
# 11069             2021-Q2  sanfrancrisko        iac     merged
#
#        days_to_resolution created_in_lockdown resolved_in_lockdown     tier  \
# 23               0.106053        pre-pandemic         pre-pandemic     Gold
# 161              0.008067        pre-pandemic         pre-pandemic     Gold
# 226             15.453669        pre-pandemic         pre-pandemic     Gold
# 252              0.835440        pre-pandemic         pre-pandemic     Gold
# 280             21.801042        pre-pandemic         pre-pandemic     Gold
# ...                   ...                 ...                  ...      ...
# 9149             0.009213        pre-pandemic         pre-pandemic  unknown
# 9662             2.801748            pandemic             pandemic  unknown
# 10332            0.017847        pre-pandemic         pre-pandemic  unknown
# 10846            0.129398            pandemic             pandemic  unknown
# 11069            4.512824            pandemic             pandemic  unknown
#
#       labels  c_counter  c_count
# 23       NaN        1.0    542.0
# 161      NaN        1.0    542.0
# 226      NaN        1.0    542.0
# 252      NaN        1.0    542.0
# 280      NaN        1.0    542.0
# ...      ...        ...      ...
# 9149     NaN        1.0      8.0
# 9662     NaN        1.0      8.0
# 10332    NaN        1.0      8.0
# 10846    NaN        1.0      8.0
# 11069    NaN        1.0      8.0
#
# [11774 rows x 18 columns]
